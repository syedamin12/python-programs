# %% [markdown]
# # ATM Machine Assignment

# %%
print('!!!!!!!\t Well Come to Swiss Bank  !!!!!!! \n')
print("*****************************************")

print('!!!!!!!\t Please Inside Your Card  !!!!!!! \n')
balance=100000
atm_pin=1234

Transcation=["b","w","m","d","c","e"]

pin=int(input('\tEnter your PIN code :\n\n'))
if pin==1234:
    print('\tChoose Your Transcation.....')
    print ('\t1. Balance Enquiry')
    print ("\t2. Withdraw Money")
    print ("\t3. Money Transfer")
    print ("\t4. Deposit")
    print ("\t5. Change PIN code ")
    print ("\t6. Exit\n")
    print("*****************************************")
    
    trans=input('\tTranscation :Choose your Transcatio\n')
    if trans=='b':
        sleep=input("\tDo you want to slip....\n").lower()
        if sleep=='yes':
            print('\t*****************')
            print('\t* Here \t\t*')
            print('\t* Your \t\t*')
            print('\t* Trans \t*')
            print('\t* Slip \t\t*')
            print('\t* Thanks \t*')
            print('\t* for \t\t*')
            print('\t* Using \t*')
            print('\t* Swiss_Bank \t*')
            print('\t*****************\n\n')
            print("*****************************************")
           
            
        else:
            print('\tSorry select the right option....')
            
    elif trans=='w':
        amount=int(input("\tEnter your Amount :\n"))
        if amount>0:
            print('\tcollect Your Cash !! : Thanks for using Swiss_Bank\n\n')
            print("*****************************************")
        else:
            print('\tSorry You have no more Balance...\n')

    elif trans=='m':
        transfer=int(input("\tEnter the Account Number where U Transfer Money :\n"))
        if transfer>12:
            print('\tYour Money has been Succefully Transfer !! : Thanks for using Swiss_Bank\n\n')
            print("*****************************************")
        else:
            print('\tSorry Check The Account Number...\n')

    elif trans=='d':
        deposit=int(input("\tEnter Your Amount to Deposit :\n"))
        if deposit>0:
            Required_balance= balance-deposit
            print('\tYour Deposit has been Succefully  !! : \n')
            print(f'\tYour Balance is  : {Required_balance}\n\n')
            print("*****************************************")
        else:
            print('\tSorry Enter Your Vaild Amount...\n')

    elif trans=='c':
        change_pin=int(input("\tEnter Your New PIN :\n"))
        if change_pin>=0:
            print('\tYour PIN has been Succefully change  !! : Thanks for using Swiss_Bank\n\n')
            print("*****************************************")
        else:
            print('\tSorry unvalid PIN code...\n')

    elif trans=='e':
        Exit=input("\tPress Yes to Exit :\n").lower()
        if Exit=='yes':
            print('\t Thanks for using Swiss_Bank\n')
            print('\t*****************')
            print('\t* Take \t\t*')
            print('\t*    \t\t*')
            print('\t* Your   \t*')
            print('\t*   \t\t*')
            print('\t* Card \t\t*')
            print('\t*  \t\t*')
            print('\t*  \t\t*')
            print('\t*****************\n\n')
            print("*****************************************")
        else:
            print('\tPlease choose any Transcation...\n')
              
            
else:
    print('\tWrong Pin!, Try again...\n')
    print("*****************************************")
# Out:
# !!!!!!!	 Well Come to Swiss Bank  !!!!!!!
#
# *****************************************
# !!!!!!!	 Please Inside Your Card  !!!!!!!
#
# 	Enter your PIN code :
#
# 1234
# 	Choose Your Transcation.....
# 	1. Balance Enquiry
# 	2. Withdraw Money
# 	3. Money Transfer
# 	4. Deposit
# 	5. Change PIN code
# 	6. Exit
#
# *****************************************
# 	Transcation :Choose your Transcatio
# e
# 	Press Yes to Exit :
# yes
# 	 Thanks for using Swiss_Bank
#
# 	*****************
# 	* Take 		*
# 	*    		*
# 	* Your   	*
# 	*   		*
# 	* Card 		*
# 	*  		*
# 	*  		*
# 	*****************
#
#
# *****************************************
